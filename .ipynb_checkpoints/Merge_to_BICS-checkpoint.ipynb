# %%
import pandas as pd
import numpy as np
import os

# %%
os.chdir('/Users/chrissoria/Documents/Research/BICS_Political_Polarization/')

# %%
all_waves = pd.read_csv('/Users/chrissoria/Documents/Research/BICS/data/df_combined.csv', low_memory=False)

# %% [markdown]
# For this preliminary analysis, I will only use wave 2,4,6. \
# Each wave's data was collected on 2020-06-17 - 2020-06-23, 2020-11-29 - 2020-12-16, 2021-05-12 - 2021-05-25.

# %%
all_waves['wave_range'].unique()
# Out:
# array(['2020-06-17 - 2020-06-23', '2020-11-29 - 2020-12-16',
#        '2021-05-12 - 2021-05-25'], dtype=object)

# %%
col_types = {
    'ZIP': str,
    'CD':str,
    'COUNTY_FIPS':str
}

ZIP_FEATURES = pd.read_csv('/Users/chrissoria/Documents/Research/BICS_Political_Polarization/data/Zip_Features.csv',
                          dtype=col_types)

# %%
col_types = {
    'resp_zip': str
}

all_waves = pd.read_csv('/Users/chrissoria/Documents/Research/BICS/data/df_combined.csv', 
                        low_memory=False, dtype=col_types)

all_waves = all_waves.rename(columns={
    'resp_zip': 'ZIP'
})

columns_to_keep = ['ResponseId','StartDate','resp_yob','resp_sex','resp_hispanic','resp_race_1','resp_race_2',
                  'resp_race_3','resp_race_4','resp_race_5','resp_race_6','resp_educ','resp_nativity','ZIP',
                  'resp_hhsize','resp_employ','resp_occupation','lefthome_num','num_cc_nonhh',
                  'lefthome_where_1','lefthome_where_2','lefthome_where_3','lefthome_where_4','lefthome_where_10',
                  'lefthome_where_8','lefthome_where_9','lefthome_where_5','lefthome_where_11','lefthome_where_6',
                  'lefthome_where_7','inet_freq','socmedia_use','covid19_familiar','covid19_concern',
                  'covid19_f2fchange','covid19_reduceOK','policy_sip','age','hhi','political_party','political_view',
                  'industry','health_insurance','interview_date','wave','agecat','city','covid19_vax','covid19_whynot_vax']
all_waves = all_waves[columns_to_keep]

# %%
BICS_ZIP_FEATURES = pd.merge(all_waves, ZIP_FEATURES, on = "ZIP", how = "left")
BICS_ZIP_FEATURES.to_csv('data/BICS_Zip_Features.csv',index=False)

# %%
BICS_ZIP_FEATURES
# Out:
#               ResponseId            StartDate  resp_yob resp_sex  \
# 0      R_10ARlAAmJ8eGNJb  2020-06-18 21:18:16      1996   Female
# 1      R_10ARlAAmJ8eGNJb  2020-06-18 21:18:16      1996   Female
# 2      R_yrmrreDsETFkB3j  2020-06-18 21:18:03      1999   Female
# 3      R_yrmrreDsETFkB3j  2020-06-18 21:18:03      1999   Female
# 4      R_yrmrreDsETFkB3j  2020-06-18 21:18:03      1999   Female
# ...                  ...                  ...       ...      ...
# 54884  R_2hL2c0J6jveA1wd  2021-05-26 17:48:09      1982     Male
# 54885  R_2hL2c0J6jveA1wd  2021-05-26 17:48:09      1982     Male
# 54886  R_1q21nl5RsYQJxJu  2021-05-26 17:59:11      1967     Male
# 54887  R_1q21nl5RsYQJxJu  2021-05-26 17:59:11      1967     Male
# 54888  R_3LXR7ok4yurdCMN  2021-05-26 21:03:26      2000     Male
#
#       resp_hispanic resp_race_1                resp_race_2 resp_race_3  \
# 0                No       White                        NaN         NaN
# 1                No       White                        NaN         NaN
# 2                No         NaN                        NaN         NaN
# 3                No         NaN                        NaN         NaN
# 4                No         NaN                        NaN         NaN
# ...             ...         ...                        ...         ...
# 54884            No         NaN                        NaN         NaN
# 54885            No         NaN                        NaN         NaN
# 54886            No         NaN  Black or African American         NaN
# 54887            No         NaN  Black or African American         NaN
# 54888           Yes       White                        NaN         NaN
#
#       resp_race_4 resp_race_5  ... COUNTY_FIPS COUNTY_TOT_RATIO  \
# 0             NaN         NaN  ...       08005         0.640926
# 1             NaN         NaN  ...       08005         0.640926
# 2           Asian         NaN  ...       37023         1.000000
# 3           Asian         NaN  ...       37023         1.000000
# 4           Asian         NaN  ...       37023         1.000000
# ...           ...         ...  ...         ...              ...
# 54884       Asian         NaN  ...       25027         1.000000
# 54885       Asian         NaN  ...       25027         1.000000
# 54886         NaN         NaN  ...       25021         1.000000
# 54887         NaN         NaN  ...       25021         1.000000
# 54888         NaN         NaN  ...       04013         1.000000
#
#              County Name COUNTY_COV_DEATHS_2020_06_20  \
# 0       Arapahoe County                         339.0
# 1       Arapahoe County                         339.0
# 2          Burke County                          17.0
# 3          Burke County                          17.0
# 4          Burke County                          17.0
# ...                  ...                          ...
# 54884  Worcester County                         897.0
# 54885  Worcester County                         897.0
# 54886    Norfolk County                         908.0
# 54887    Norfolk County                         908.0
# 54888   Maricopa County                         632.0
#
#        COUNTY_COV_DEATHS_2020_12_09 COUNTY_COV_DEATHS_2021_05_19  \
# 0                             475.0                        735.0
# 1                             475.0                        735.0
# 2                              68.0                        153.0
# 3                              68.0                        153.0
# 4                              68.0                        153.0
# ...                             ...                          ...
# 54884                        1336.0                       2218.0
# 54885                        1336.0                       2218.0
# 54886                        1200.0                       1780.0
# 54887                        1200.0                       1780.0
# 54888                        4213.0                       9974.0
#
#                STNAME           CTYNAME  ESTIMATESBASE2020 DEATHS2020
# 0            Colorado   Arapahoe County           655070.0     1258.0
# 1            Colorado   Arapahoe County           655070.0     1258.0
# 2             Georgia      Burke County            24596.0       75.0
# 3      North Carolina      Burke County            87570.0      323.0
# 4        North Dakota      Burke County             2201.0       12.0
# ...               ...               ...                ...        ...
# 54884        Maryland  Worcester County            52460.0      205.0
# 54885   Massachusetts  Worcester County           862111.0     2094.0
# 54886   Massachusetts    Norfolk County           725981.0     1664.0
# 54887   Massachusetts    Norfolk County           725981.0     1664.0
# 54888         Arizona   Maricopa County          4420568.0     9912.0
#
# [54889 rows x 64 columns]
